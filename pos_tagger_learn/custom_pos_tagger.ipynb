# %%
import nltk
import pprint 
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline

# %% [markdown]
# Import data which is tagged

# %%
# tagged_sentences = nltk.corpus.brown.tagged_sents()
tagged_sentences = nltk.corpus.treebank.tagged_sents()
 
print(tagged_sentences[0])
print("Tagged sentences: ", len(tagged_sentences))
print("Tagged words:", len(nltk.corpus.brown.tagged_words()))
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'CD'), ('years', 'NNS'), ('old', 'JJ'), (',', ','), ('will', 'MD'), ('join', 'VB'), ('the', 'DT'), ('board', 'NN'), ('as', 'IN'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')]
# Tagged sentences:  3914
# Tagged words: 1161192

# %% [markdown]
# Training our own POS Tagger using scikit-learn
#
# Before starting training a classifier, we must agree first on what features to use. Most obvious choices are: the word itself, the word before and the word after. That’s a good start, but we can do so much better. For example, the 2-letter suffix is a great indicator of past-tense verbs, ending in “-ed”. 3-letter suffix helps recognize the present participle ending in “-ing”.

# %%
def features(sentence, index):
    """ sentence: [w1, w2, ...], index: the index of the word """
    return {
        'word': sentence[index],
        'is_first': index == 0,
        'is_last': index == len(sentence) - 1,
        'is_capitalized': sentence[index][0].upper() == sentence[index][0],
        'is_all_caps': sentence[index].upper() == sentence[index],
        'is_all_lower': sentence[index].lower() == sentence[index],
        'prefix-1': sentence[index][0],
        'prefix-2': sentence[index][:2],
        'prefix-3': sentence[index][:3],
        'suffix-1': sentence[index][-1],
        'suffix-2': sentence[index][-2:],
        'suffix-3': sentence[index][-3:],
        'prev_word': '' if index == 0 else sentence[index - 1],
        'next_word': '' if index == len(sentence) - 1 else sentence[index + 1],
        'has_hyphen': '-' in sentence[index],
        'is_numeric': sentence[index].isdigit(),
        'capitals_inside': sentence[index][1:].lower() != sentence[index][1:]
    }
 

pprint.pprint(features(['This', 'is', 'a', 'sentence'], 2))
 
{'capitals_inside': False,
 'has_hyphen': False,
 'is_all_caps': False,
 'is_all_lower': True,
 'is_capitalized': False,
 'is_first': False,
 'is_last': False,
 'is_numeric': False,
 'next_word': 'sentence',
 'prefix-1': 'a',
 'prefix-2': 'a',
 'prefix-3': 'a',
 'prev_word': 'is',
 'suffix-1': 'a',
 'suffix-2': 'a',
 'suffix-3': 'a',
 'word': 'a'}
# Out:
# {'capitals_inside': False,
#  'has_hyphen': False,
#  'is_all_caps': False,
#  'is_all_lower': True,
#  'is_capitalized': False,
#  'is_first': False,
#  'is_last': False,
#  'is_numeric': False,
#  'next_word': 'sentence',
#  'prefix-1': 'a',
#  'prefix-2': 'a',
#  'prefix-3': 'a',
#  'prev_word': 'is',
#  'suffix-1': 'a',
#  'suffix-2': 'a',
#  'suffix-3': 'a',
#  'word': 'a'}
# {'capitals_inside': False,
#  'has_hyphen': False,
#  'is_all_caps': False,
#  'is_all_lower': True,
#  'is_capitalized': False,
#  'is_first': False,
#  'is_last': False,
#  'is_numeric': False,
#  'next_word': 'sentence',
#  'prefix-1': 'a',
#  'prefix-2': 'a',
#  'prefix-3': 'a',
#  'prev_word': 'is',
#  'suffix-1': 'a',
#  'suffix-2': 'a',
#  'suffix-3': 'a',
#  'word': 'a'}

# %% [markdown]
# Small helper function to strip the tags from our tagged corpus and feed it to our classifier:

# %%
def untag(tagged_sentence):
    return [w for w, t in tagged_sentence]

# %% [markdown]
# Let’s now build our training set. Our classifier should accept features for a single word, but our corpus is composed of sentences. We’ll need to do some transformations:

# %%
# Split the dataset for training and testing
cutoff = int(.75 * len(tagged_sentences))
training_sentences = tagged_sentences[:cutoff]
test_sentences = tagged_sentences[cutoff:]
 
print(len(training_sentences) )  # 2935
print(len(test_sentences) )        # 979
 
def transform_to_dataset(tagged_sentences):
    X, y = [], []
 
    for tagged in tagged_sentences:
        for index in range(len(tagged)):
            X.append(features(untag(tagged), index))
            y.append(tagged[index][1])
 
    return X, y
 
X, y = transform_to_dataset(training_sentences)
# Out:
# 2935
# 979

# %% [markdown]
# We’re now ready to train the classifier. I’ve opted for a DecisionTreeClassifier. Feel free to play with others:

# %%
clf = Pipeline([
    ('vectorizer', DictVectorizer(sparse=False)),
    ('classifier', DecisionTreeClassifier(criterion='entropy'))
])
 
clf.fit(X[:10000], y[:10000])   # Use only the first 10K samples if you're running it multiple times. It takes a fair bit :)
 
print('Training completed')
 
X_test, y_test = transform_to_dataset(test_sentences)
 
print("Accuracy:", clf.score(X_test, y_test))
# Out:
# Training completed
# Accuracy: 0.897959183673

# %% [markdown]
# Let’s tag!
#
# We can now use our classifier like this:

# %%
X_test
# Out:
# [{'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': True,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'can',
#   'prefix-1': 'W',
#   'prefix-2': 'We',
#   'prefix-3': 'We',
#   'prev_word': '',
#   'suffix-1': 'e',
#   'suffix-2': 'We',
#   'suffix-3': 'We',
#   'word': 'We'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'understand',
#   'prefix-1': 'c',
#   'prefix-2': 'ca',
#   'prefix-3': 'can',
#   'prev_word': 'We',
#   'suffix-1': 'n',
#   'suffix-2': 'an',
#   'suffix-3': 'can',
#   'word': 'can'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'and',
#   'prefix-1': 'u',
#   'prefix-2': 'un',
#   'prefix-3': 'und',
#   'prev_word': 'can',
#   'suffix-1': 'd',
#   'suffix-2': 'nd',
#   'suffix-3': 'and',
#   'word': 'understand'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'share',
#   'prefix-1': 'a',
#   'prefix-2': 'an',
#   'prefix-3': 'and',
#   'prev_word': 'understand',
#   'suffix-1': 'd',
#   'suffix-2': 'nd',
#   'suffix-3': 'and',
#   'word': 'and'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 's',
#   'prefix-2': 'sh',
#   'prefix-3': 'sha',
#   'prev_word': 'and',
#   'suffix-1': 'e',
#   'suffix-2': 're',
#   'suffix-3': 'are',
#   'word': 'share'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'compassion',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'share',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'that',
#   'prefix-1': 'c',
#   'prefix-2': 'co',
#   'prefix-3': 'com',
#   'prev_word': 'the',
#   'suffix-1': 'n',
#   'suffix-2': 'on',
#   'suffix-3': 'ion',
#   'word': 'compassion'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*T*-2',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'tha',
#   'prev_word': 'compassion',
#   'suffix-1': 't',
#   'suffix-2': 'at',
#   'suffix-3': 'hat',
#   'word': 'that'},
#  {'capitals_inside': True,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'makes',
#   'prefix-1': '*',
#   'prefix-2': '*T',
#   'prefix-3': '*T*',
#   'prev_word': 'that',
#   'suffix-1': '2',
#   'suffix-2': '-2',
#   'suffix-3': '*-2',
#   'word': '*T*-2'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'judges',
#   'prefix-1': 'm',
#   'prefix-2': 'ma',
#   'prefix-3': 'mak',
#   'prev_word': '*T*-2',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'kes',
#   'word': 'makes'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'sometimes',
#   'prefix-1': 'j',
#   'prefix-2': 'ju',
#   'prefix-3': 'jud',
#   'prev_word': 'makes',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'ges',
#   'word': 'judges'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'wish',
#   'prefix-1': 's',
#   'prefix-2': 'so',
#   'prefix-3': 'som',
#   'prev_word': 'judges',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'mes',
#   'word': 'sometimes'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*-3',
#   'prefix-1': 'w',
#   'prefix-2': 'wi',
#   'prefix-3': 'wis',
#   'prev_word': 'sometimes',
#   'suffix-1': 'h',
#   'suffix-2': 'sh',
#   'suffix-3': 'ish',
#   'word': 'wish'},
#  {'capitals_inside': False,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'to',
#   'prefix-1': '*',
#   'prefix-2': '*-',
#   'prefix-3': '*-3',
#   'prev_word': 'wish',
#   'suffix-1': '3',
#   'suffix-2': '-3',
#   'suffix-3': '*-3',
#   'word': '*-3'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'offer',
#   'prefix-1': 't',
#   'prefix-2': 'to',
#   'prefix-3': 'to',
#   'prev_word': '*-3',
#   'suffix-1': 'o',
#   'suffix-2': 'to',
#   'suffix-3': 'to',
#   'word': 'to'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'a',
#   'prefix-1': 'o',
#   'prefix-2': 'of',
#   'prefix-3': 'off',
#   'prev_word': 'to',
#   'suffix-1': 'r',
#   'suffix-2': 'er',
#   'suffix-3': 'fer',
#   'word': 'offer'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'kind',
#   'prefix-1': 'a',
#   'prefix-2': 'a',
#   'prefix-3': 'a',
#   'prev_word': 'offer',
#   'suffix-1': 'a',
#   'suffix-2': 'a',
#   'suffix-3': 'a',
#   'word': 'a'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'of',
#   'prefix-1': 'k',
#   'prefix-2': 'ki',
#   'prefix-3': 'kin',
#   'prev_word': 'a',
#   'suffix-1': 'd',
#   'suffix-2': 'nd',
#   'suffix-3': 'ind',
#   'word': 'kind'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'Solomonic',
#   'prefix-1': 'o',
#   'prefix-2': 'of',
#   'prefix-3': 'of',
#   'prev_word': 'kind',
#   'suffix-1': 'f',
#   'suffix-2': 'of',
#   'suffix-3': 'of',
#   'word': 'of'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'aid',
#   'prefix-1': 'S',
#   'prefix-2': 'So',
#   'prefix-3': 'Sol',
#   'prev_word': 'of',
#   'suffix-1': 'c',
#   'suffix-2': 'ic',
#   'suffix-3': 'nic',
#   'word': 'Solomonic'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'to',
#   'prefix-1': 'a',
#   'prefix-2': 'ai',
#   'prefix-3': 'aid',
#   'prev_word': 'Solomonic',
#   'suffix-1': 'd',
#   'suffix-2': 'id',
#   'suffix-3': 'aid',
#   'word': 'aid'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'those',
#   'prefix-1': 't',
#   'prefix-2': 'to',
#   'prefix-3': 'to',
#   'prev_word': 'aid',
#   'suffix-1': 'o',
#   'suffix-2': 'to',
#   'suffix-3': 'to',
#   'word': 'to'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'who',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'tho',
#   'prev_word': 'to',
#   'suffix-1': 'e',
#   'suffix-2': 'se',
#   'suffix-3': 'ose',
#   'word': 'those'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*T*-4',
#   'prefix-1': 'w',
#   'prefix-2': 'wh',
#   'prefix-3': 'who',
#   'prev_word': 'those',
#   'suffix-1': 'o',
#   'suffix-2': 'ho',
#   'suffix-3': 'who',
#   'word': 'who'},
#  {'capitals_inside': True,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': "'ve",
#   'prefix-1': '*',
#   'prefix-2': '*T',
#   'prefix-3': '*T*',
#   'prev_word': 'who',
#   'suffix-1': '4',
#   'suffix-2': '-4',
#   'suffix-3': '*-4',
#   'word': '*T*-4'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'been',
#   'prefix-1': "'",
#   'prefix-2': "'v",
#   'prefix-3': "'ve",
#   'prev_word': '*T*-4',
#   'suffix-1': 'e',
#   'suffix-2': 've',
#   'suffix-3': "'ve",
#   'word': "'ve"},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'hurt',
#   'prefix-1': 'b',
#   'prefix-2': 'be',
#   'prefix-3': 'bee',
#   'prev_word': "'ve",
#   'suffix-1': 'n',
#   'suffix-2': 'en',
#   'suffix-3': 'een',
#   'word': 'been'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*-1',
#   'prefix-1': 'h',
#   'prefix-2': 'hu',
#   'prefix-3': 'hur',
#   'prev_word': 'been',
#   'suffix-1': 't',
#   'suffix-2': 'rt',
#   'suffix-3': 'urt',
#   'word': 'hurt'},
#  {'capitals_inside': False,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '.',
#   'prefix-1': '*',
#   'prefix-2': '*-',
#   'prefix-3': '*-1',
#   'prev_word': 'hurt',
#   'suffix-1': '1',
#   'suffix-2': '-1',
#   'suffix-3': '*-1',
#   'word': '*-1'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': True,
#   'is_numeric': False,
#   'next_word': '',
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'prev_word': '*-1',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'word': '.'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': True,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'this',
#   'prefix-1': 'B',
#   'prefix-2': 'Bu',
#   'prefix-3': 'But',
#   'prev_word': '',
#   'suffix-1': 't',
#   'suffix-2': 'ut',
#   'suffix-3': 'But',
#   'word': 'But'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'case',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'thi',
#   'prev_word': 'But',
#   'suffix-1': 's',
#   'suffix-2': 'is',
#   'suffix-3': 'his',
#   'word': 'this'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'is',
#   'prefix-1': 'c',
#   'prefix-2': 'ca',
#   'prefix-3': 'cas',
#   'prev_word': 'this',
#   'suffix-1': 'e',
#   'suffix-2': 'se',
#   'suffix-3': 'ase',
#   'word': 'case'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'a',
#   'prefix-1': 'i',
#   'prefix-2': 'is',
#   'prefix-3': 'is',
#   'prev_word': 'case',
#   'suffix-1': 's',
#   'suffix-2': 'is',
#   'suffix-3': 'is',
#   'word': 'is'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'stark',
#   'prefix-1': 'a',
#   'prefix-2': 'a',
#   'prefix-3': 'a',
#   'prev_word': 'is',
#   'suffix-1': 'a',
#   'suffix-2': 'a',
#   'suffix-3': 'a',
#   'word': 'a'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'lesson',
#   'prefix-1': 's',
#   'prefix-2': 'st',
#   'prefix-3': 'sta',
#   'prev_word': 'a',
#   'suffix-1': 'k',
#   'suffix-2': 'rk',
#   'suffix-3': 'ark',
#   'word': 'stark'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'in',
#   'prefix-1': 'l',
#   'prefix-2': 'le',
#   'prefix-3': 'les',
#   'prev_word': 'stark',
#   'suffix-1': 'n',
#   'suffix-2': 'on',
#   'suffix-3': 'son',
#   'word': 'lesson'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'how',
#   'prefix-1': 'i',
#   'prefix-2': 'in',
#   'prefix-3': 'in',
#   'prev_word': 'lesson',
#   'suffix-1': 'n',
#   'suffix-2': 'in',
#   'suffix-3': 'in',
#   'word': 'in'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'h',
#   'prefix-2': 'ho',
#   'prefix-3': 'how',
#   'prev_word': 'in',
#   'suffix-1': 'w',
#   'suffix-2': 'ow',
#   'suffix-3': 'how',
#   'word': 'how'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'failures',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'how',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'of',
#   'prefix-1': 'f',
#   'prefix-2': 'fa',
#   'prefix-3': 'fai',
#   'prev_word': 'the',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'res',
#   'word': 'failures'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'o',
#   'prefix-2': 'of',
#   'prefix-3': 'of',
#   'prev_word': 'failures',
#   'suffix-1': 'f',
#   'suffix-2': 'of',
#   'suffix-3': 'of',
#   'word': 'of'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'traditional',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'of',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'policy-making',
#   'prefix-1': 't',
#   'prefix-2': 'tr',
#   'prefix-3': 'tra',
#   'prev_word': 'the',
#   'suffix-1': 'l',
#   'suffix-2': 'al',
#   'suffix-3': 'nal',
#   'word': 'traditional'},
#  {'capitals_inside': False,
#   'has_hyphen': True,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'process',
#   'prefix-1': 'p',
#   'prefix-2': 'po',
#   'prefix-3': 'pol',
#   'prev_word': 'traditional',
#   'suffix-1': 'g',
#   'suffix-2': 'ng',
#   'suffix-3': 'ing',
#   'word': 'policy-making'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'have',
#   'prefix-1': 'p',
#   'prefix-2': 'pr',
#   'prefix-3': 'pro',
#   'prev_word': 'policy-making',
#   'suffix-1': 's',
#   'suffix-2': 'ss',
#   'suffix-3': 'ess',
#   'word': 'process'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'left',
#   'prefix-1': 'h',
#   'prefix-2': 'ha',
#   'prefix-3': 'hav',
#   'prev_word': 'process',
#   'suffix-1': 'e',
#   'suffix-2': 've',
#   'suffix-3': 'ave',
#   'word': 'have'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'l',
#   'prefix-2': 'le',
#   'prefix-3': 'lef',
#   'prev_word': 'have',
#   'suffix-1': 't',
#   'suffix-2': 'ft',
#   'suffix-3': 'eft',
#   'word': 'left'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'courts',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'left',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'as',
#   'prefix-1': 'c',
#   'prefix-2': 'co',
#   'prefix-3': 'cou',
#   'prev_word': 'the',
#   'suffix-1': 's',
#   'suffix-2': 'ts',
#   'suffix-3': 'rts',
#   'word': 'courts'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'a',
#   'prefix-2': 'as',
#   'prefix-3': 'as',
#   'prev_word': 'courts',
#   'suffix-1': 's',
#   'suffix-2': 'as',
#   'suffix-3': 'as',
#   'word': 'as'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'only',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'as',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'forum',
#   'prefix-1': 'o',
#   'prefix-2': 'on',
#   'prefix-3': 'onl',
#   'prev_word': 'the',
#   'suffix-1': 'y',
#   'suffix-2': 'ly',
#   'suffix-3': 'nly',
#   'word': 'only'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '0',
#   'prefix-1': 'f',
#   'prefix-2': 'fo',
#   'prefix-3': 'for',
#   'prev_word': 'only',
#   'suffix-1': 'm',
#   'suffix-2': 'um',
#   'suffix-3': 'rum',
#   'word': 'forum'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': True,
#   'next_word': 'this',
#   'prefix-1': '0',
#   'prefix-2': '0',
#   'prefix-3': '0',
#   'prev_word': 'forum',
#   'suffix-1': '0',
#   'suffix-2': '0',
#   'suffix-3': '0',
#   'word': '0'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'country',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'thi',
#   'prev_word': '0',
#   'suffix-1': 's',
#   'suffix-2': 'is',
#   'suffix-3': 'his',
#   'word': 'this'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'has',
#   'prefix-1': 'c',
#   'prefix-2': 'co',
#   'prefix-3': 'cou',
#   'prev_word': 'this',
#   'suffix-1': 'y',
#   'suffix-2': 'ry',
#   'suffix-3': 'try',
#   'word': 'country'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*T*-2',
#   'prefix-1': 'h',
#   'prefix-2': 'ha',
#   'prefix-3': 'has',
#   'prev_word': 'country',
#   'suffix-1': 's',
#   'suffix-2': 'as',
#   'suffix-3': 'has',
#   'word': 'has'},
#  {'capitals_inside': True,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '0',
#   'prefix-1': '*',
#   'prefix-2': '*T',
#   'prefix-3': '*T*',
#   'prev_word': 'has',
#   'suffix-1': '2',
#   'suffix-2': '-2',
#   'suffix-3': '*-2',
#   'word': '*T*-2'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': True,
#   'next_word': '*',
#   'prefix-1': '0',
#   'prefix-2': '0',
#   'prefix-3': '0',
#   'prev_word': '*T*-2',
#   'suffix-1': '0',
#   'suffix-2': '0',
#   'suffix-3': '0',
#   'word': '0'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'to',
#   'prefix-1': '*',
#   'prefix-2': '*',
#   'prefix-3': '*',
#   'prev_word': '0',
#   'suffix-1': '*',
#   'suffix-2': '*',
#   'suffix-3': '*',
#   'word': '*'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'debate',
#   'prefix-1': 't',
#   'prefix-2': 'to',
#   'prefix-3': 'to',
#   'prev_word': '*',
#   'suffix-1': 'o',
#   'suffix-2': 'to',
#   'suffix-3': 'to',
#   'word': 'to'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'risk',
#   'prefix-1': 'd',
#   'prefix-2': 'de',
#   'prefix-3': 'deb',
#   'prev_word': 'to',
#   'suffix-1': 'e',
#   'suffix-2': 'te',
#   'suffix-3': 'ate',
#   'word': 'debate'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': ',',
#   'prefix-1': 'r',
#   'prefix-2': 'ri',
#   'prefix-3': 'ris',
#   'prev_word': 'debate',
#   'suffix-1': 'k',
#   'suffix-2': 'sk',
#   'suffix-3': 'isk',
#   'word': 'risk'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'technology',
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'prev_word': 'risk',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'word': ','},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'and',
#   'prefix-1': 't',
#   'prefix-2': 'te',
#   'prefix-3': 'tec',
#   'prev_word': ',',
#   'suffix-1': 'y',
#   'suffix-2': 'gy',
#   'suffix-3': 'ogy',
#   'word': 'technology'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'innovation',
#   'prefix-1': 'a',
#   'prefix-2': 'an',
#   'prefix-3': 'and',
#   'prev_word': 'technology',
#   'suffix-1': 'd',
#   'suffix-2': 'nd',
#   'suffix-3': 'and',
#   'word': 'and'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*T*-3',
#   'prefix-1': 'i',
#   'prefix-2': 'in',
#   'prefix-3': 'inn',
#   'prev_word': 'and',
#   'suffix-1': 'n',
#   'suffix-2': 'on',
#   'suffix-3': 'ion',
#   'word': 'innovation'},
#  {'capitals_inside': True,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*T*-1',
#   'prefix-1': '*',
#   'prefix-2': '*T',
#   'prefix-3': '*T*',
#   'prev_word': 'innovation',
#   'suffix-1': '3',
#   'suffix-2': '-3',
#   'suffix-3': '*-3',
#   'word': '*T*-3'},
#  {'capitals_inside': True,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '.',
#   'prefix-1': '*',
#   'prefix-2': '*T',
#   'prefix-3': '*T*',
#   'prev_word': '*T*-3',
#   'suffix-1': '1',
#   'suffix-2': '-1',
#   'suffix-3': '*-1',
#   'word': '*T*-1'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': True,
#   'is_numeric': False,
#   'next_word': '',
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'prev_word': '*T*-1',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'word': '.'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': True,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'often',
#   'prefix-1': 'T',
#   'prefix-2': 'To',
#   'prefix-3': 'Too',
#   'prev_word': '',
#   'suffix-1': 'o',
#   'suffix-2': 'oo',
#   'suffix-3': 'Too',
#   'word': 'Too'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'now',
#   'prefix-1': 'o',
#   'prefix-2': 'of',
#   'prefix-3': 'oft',
#   'prev_word': 'Too',
#   'suffix-1': 'n',
#   'suffix-2': 'en',
#   'suffix-3': 'ten',
#   'word': 'often'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': ',',
#   'prefix-1': 'n',
#   'prefix-2': 'no',
#   'prefix-3': 'now',
#   'prev_word': 'often',
#   'suffix-1': 'w',
#   'suffix-2': 'ow',
#   'suffix-3': 'now',
#   'word': 'now'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'a',
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'prev_word': 'now',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'word': ','},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'single',
#   'prefix-1': 'a',
#   'prefix-2': 'a',
#   'prefix-3': 'a',
#   'prev_word': ',',
#   'suffix-1': 'a',
#   'suffix-2': 'a',
#   'suffix-3': 'a',
#   'word': 'a'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'court',
#   'prefix-1': 's',
#   'prefix-2': 'si',
#   'prefix-3': 'sin',
#   'prev_word': 'a',
#   'suffix-1': 'e',
#   'suffix-2': 'le',
#   'suffix-3': 'gle',
#   'word': 'single'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'decision',
#   'prefix-1': 'c',
#   'prefix-2': 'co',
#   'prefix-3': 'cou',
#   'prev_word': 'single',
#   'suffix-1': 't',
#   'suffix-2': 'rt',
#   'suffix-3': 'urt',
#   'word': 'court'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'becomes',
#   'prefix-1': 'd',
#   'prefix-2': 'de',
#   'prefix-3': 'dec',
#   'prev_word': 'court',
#   'suffix-1': 'n',
#   'suffix-2': 'on',
#   'suffix-3': 'ion',
#   'word': 'decision'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'b',
#   'prefix-2': 'be',
#   'prefix-3': 'bec',
#   'prev_word': 'decision',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'mes',
#   'word': 'becomes'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'precedent',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'becomes',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'for',
#   'prefix-1': 'p',
#   'prefix-2': 'pr',
#   'prefix-3': 'pre',
#   'prev_word': 'the',
#   'suffix-1': 't',
#   'suffix-2': 'nt',
#   'suffix-3': 'ent',
#   'word': 'precedent'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'other',
#   'prefix-1': 'f',
#   'prefix-2': 'fo',
#   'prefix-3': 'for',
#   'prev_word': 'precedent',
#   'suffix-1': 'r',
#   'suffix-2': 'or',
#   'suffix-3': 'for',
#   'word': 'for'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': ',',
#   'prefix-1': 'o',
#   'prefix-2': 'ot',
#   'prefix-3': 'oth',
#   'prev_word': 'for',
#   'suffix-1': 'r',
#   'suffix-2': 'er',
#   'suffix-3': 'her',
#   'word': 'other'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'less',
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'prev_word': 'other',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'word': ','},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'compelling',
#   'prefix-1': 'l',
#   'prefix-2': 'le',
#   'prefix-3': 'les',
#   'prev_word': ',',
#   'suffix-1': 's',
#   'suffix-2': 'ss',
#   'suffix-3': 'ess',
#   'word': 'less'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'cases',
#   'prefix-1': 'c',
#   'prefix-2': 'co',
#   'prefix-3': 'com',
#   'prev_word': 'less',
#   'suffix-1': 'g',
#   'suffix-2': 'ng',
#   'suffix-3': 'ing',
#   'word': 'compelling'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '.',
#   'prefix-1': 'c',
#   'prefix-2': 'ca',
#   'prefix-3': 'cas',
#   'prev_word': 'compelling',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'ses',
#   'word': 'cases'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': True,
#   'is_numeric': False,
#   'next_word': '',
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'prev_word': 'cases',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'word': '.'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': True,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'F',
#   'prefix-2': 'Fr',
#   'prefix-3': 'Fro',
#   'prev_word': '',
#   'suffix-1': 'm',
#   'suffix-2': 'om',
#   'suffix-3': 'rom',
#   'word': 'From'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '1940s',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'From',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'until',
#   'prefix-1': '1',
#   'prefix-2': '19',
#   'prefix-3': '194',
#   'prev_word': 'the',
#   'suffix-1': 's',
#   'suffix-2': '0s',
#   'suffix-3': '40s',
#   'word': '1940s'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '1971',
#   'prefix-1': 'u',
#   'prefix-2': 'un',
#   'prefix-3': 'unt',
#   'prev_word': '1940s',
#   'suffix-1': 'l',
#   'suffix-2': 'il',
#   'suffix-3': 'til',
#   'word': 'until'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': True,
#   'next_word': ',',
#   'prefix-1': '1',
#   'prefix-2': '19',
#   'prefix-3': '197',
#   'prev_word': 'until',
#   'suffix-1': '1',
#   'suffix-2': '71',
#   'suffix-3': '971',
#   'word': '1971'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'some',
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'prev_word': '1971',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'word': ','},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'two',
#   'prefix-1': 's',
#   'prefix-2': 'so',
#   'prefix-3': 'som',
#   'prev_word': ',',
#   'suffix-1': 'e',
#   'suffix-2': 'me',
#   'suffix-3': 'ome',
#   'word': 'some'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'million',
#   'prefix-1': 't',
#   'prefix-2': 'tw',
#   'prefix-3': 'two',
#   'prev_word': 'some',
#   'suffix-1': 'o',
#   'suffix-2': 'wo',
#   'suffix-3': 'two',
#   'word': 'two'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'women',
#   'prefix-1': 'm',
#   'prefix-2': 'mi',
#   'prefix-3': 'mil',
#   'prev_word': 'two',
#   'suffix-1': 'n',
#   'suffix-2': 'on',
#   'suffix-3': 'ion',
#   'word': 'million'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'took',
#   'prefix-1': 'w',
#   'prefix-2': 'wo',
#   'prefix-3': 'wom',
#   'prev_word': 'million',
#   'suffix-1': 'n',
#   'suffix-2': 'en',
#   'suffix-3': 'men',
#   'word': 'women'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 't',
#   'prefix-2': 'to',
#   'prefix-3': 'too',
#   'prev_word': 'women',
#   'suffix-1': 'k',
#   'suffix-2': 'ok',
#   'suffix-3': 'ook',
#   'word': 'took'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'synthetic',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'took',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'hormone',
#   'prefix-1': 's',
#   'prefix-2': 'sy',
#   'prefix-3': 'syn',
#   'prev_word': 'the',
#   'suffix-1': 'c',
#   'suffix-2': 'ic',
#   'suffix-3': 'tic',
#   'word': 'synthetic'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'diethylstilbestrol',
#   'prefix-1': 'h',
#   'prefix-2': 'ho',
#   'prefix-3': 'hor',
#   'prev_word': 'synthetic',
#   'suffix-1': 'e',
#   'suffix-2': 'ne',
#   'suffix-3': 'one',
#   'word': 'hormone'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '-LRB-',
#   'prefix-1': 'd',
#   'prefix-2': 'di',
#   'prefix-3': 'die',
#   'prev_word': 'hormone',
#   'suffix-1': 'l',
#   'suffix-2': 'ol',
#   'suffix-3': 'rol',
#   'word': 'diethylstilbestrol'},
#  {'capitals_inside': True,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'DES',
#   'prefix-1': '-',
#   'prefix-2': '-L',
#   'prefix-3': '-LR',
#   'prev_word': 'diethylstilbestrol',
#   'suffix-1': '-',
#   'suffix-2': 'B-',
#   'suffix-3': 'RB-',
#   'word': '-LRB-'},
#  {'capitals_inside': True,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '-RRB-',
#   'prefix-1': 'D',
#   'prefix-2': 'DE',
#   'prefix-3': 'DES',
#   'prev_word': '-LRB-',
#   'suffix-1': 'S',
#   'suffix-2': 'ES',
#   'suffix-3': 'DES',
#   'word': 'DES'},
#  {'capitals_inside': True,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*-1',
#   'prefix-1': '-',
#   'prefix-2': '-R',
#   'prefix-3': '-RR',
#   'prev_word': 'DES',
#   'suffix-1': '-',
#   'suffix-2': 'B-',
#   'suffix-3': 'RB-',
#   'word': '-RRB-'},
#  {'capitals_inside': False,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'to',
#   'prefix-1': '*',
#   'prefix-2': '*-',
#   'prefix-3': '*-1',
#   'prev_word': '-RRB-',
#   'suffix-1': '1',
#   'suffix-2': '-1',
#   'suffix-3': '*-1',
#   'word': '*-1'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'prevent',
#   'prefix-1': 't',
#   'prefix-2': 'to',
#   'prefix-3': 'to',
#   'prev_word': '*-1',
#   'suffix-1': 'o',
#   'suffix-2': 'to',
#   'suffix-3': 'to',
#   'word': 'to'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'miscarriages',
#   'prefix-1': 'p',
#   'prefix-2': 'pr',
#   'prefix-3': 'pre',
#   'prev_word': 'to',
#   'suffix-1': 't',
#   'suffix-2': 'nt',
#   'suffix-3': 'ent',
#   'word': 'prevent'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'and',
#   'prefix-1': 'm',
#   'prefix-2': 'mi',
#   'prefix-3': 'mis',
#   'prev_word': 'prevent',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'ges',
#   'word': 'miscarriages'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'morning',
#   'prefix-1': 'a',
#   'prefix-2': 'an',
#   'prefix-3': 'and',
#   'prev_word': 'miscarriages',
#   'suffix-1': 'd',
#   'suffix-2': 'nd',
#   'suffix-3': 'and',
#   'word': 'and'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'sickness',
#   'prefix-1': 'm',
#   'prefix-2': 'mo',
#   'prefix-3': 'mor',
#   'prev_word': 'and',
#   'suffix-1': 'g',
#   'suffix-2': 'ng',
#   'suffix-3': 'ing',
#   'word': 'morning'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '.',
#   'prefix-1': 's',
#   'prefix-2': 'si',
#   'prefix-3': 'sic',
#   'prev_word': 'morning',
#   'suffix-1': 's',
#   'suffix-2': 'ss',
#   'suffix-3': 'ess',
#   'word': 'sickness'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': True,
#   'is_numeric': False,
#   'next_word': '',
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'prev_word': 'sickness',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'word': '.'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': True,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'drug',
#   'prefix-1': 'T',
#   'prefix-2': 'Th',
#   'prefix-3': 'The',
#   'prev_word': '',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'The',
#   'word': 'The'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'was',
#   'prefix-1': 'd',
#   'prefix-2': 'dr',
#   'prefix-3': 'dru',
#   'prev_word': 'The',
#   'suffix-1': 'g',
#   'suffix-2': 'ug',
#   'suffix-3': 'rug',
#   'word': 'drug'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'approved',
#   'prefix-1': 'w',
#   'prefix-2': 'wa',
#   'prefix-3': 'was',
#   'prev_word': 'drug',
#   'suffix-1': 's',
#   'suffix-2': 'as',
#   'suffix-3': 'was',
#   'word': 'was'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*-1',
#   'prefix-1': 'a',
#   'prefix-2': 'ap',
#   'prefix-3': 'app',
#   'prev_word': 'was',
#   'suffix-1': 'd',
#   'suffix-2': 'ed',
#   'suffix-3': 'ved',
#   'word': 'approved'},
#  {'capitals_inside': False,
#   'has_hyphen': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'by',
#   'prefix-1': '*',
#   'prefix-2': '*-',
#   'prefix-3': '*-1',
#   'prev_word': 'approved',
#   'suffix-1': '1',
#   'suffix-2': '-1',
#   'suffix-3': '*-1',
#   'word': '*-1'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'b',
#   'prefix-2': 'by',
#   'prefix-3': 'by',
#   'prev_word': '*-1',
#   'suffix-1': 'y',
#   'suffix-2': 'by',
#   'suffix-3': 'by',
#   'word': 'by'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'Food',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'by',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'and',
#   'prefix-1': 'F',
#   'prefix-2': 'Fo',
#   'prefix-3': 'Foo',
#   'prev_word': 'the',
#   'suffix-1': 'd',
#   'suffix-2': 'od',
#   'suffix-3': 'ood',
#   'word': 'Food'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'Drug',
#   'prefix-1': 'a',
#   'prefix-2': 'an',
#   'prefix-3': 'and',
#   'prev_word': 'Food',
#   'suffix-1': 'd',
#   'suffix-2': 'nd',
#   'suffix-3': 'and',
#   'word': 'and'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'Administration',
#   'prefix-1': 'D',
#   'prefix-2': 'Dr',
#   'prefix-3': 'Dru',
#   'prev_word': 'and',
#   'suffix-1': 'g',
#   'suffix-2': 'ug',
#   'suffix-3': 'rug',
#   'word': 'Drug'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'and',
#   'prefix-1': 'A',
#   'prefix-2': 'Ad',
#   'prefix-3': 'Adm',
#   'prev_word': 'Drug',
#   'suffix-1': 'n',
#   'suffix-2': 'on',
#   'suffix-3': 'ion',
#   'word': 'Administration'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'marketed',
#   'prefix-1': 'a',
#   'prefix-2': 'an',
#   'prefix-3': 'and',
#   'prev_word': 'Administration',
#   'suffix-1': 'd',
#   'suffix-2': 'nd',
#   'suffix-3': 'and',
#   'word': 'and'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*-1',
#   'prefix-1': 'm',
#   'prefix-2': 'ma',
#   'prefix-3': 'mar',
#   'prev_word': 'and',
#   'suffix-1': 'd',
#   'suffix-2': 'ed',
#   'suffix-3': 'ted',
# ...
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'department',
#   'prefix-1': 'w',
#   'prefix-2': 'we',
#   'prefix-3': 'wel',
#   'prev_word': 'such',
#   'suffix-1': 'n',
#   'suffix-2': 'wn',
#   'suffix-3': 'own',
#   'word': 'well-known'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'stores',
#   'prefix-1': 'd',
#   'prefix-2': 'de',
#   'prefix-3': 'dep',
#   'prev_word': 'well-known',
#   'suffix-1': 't',
#   'suffix-2': 'nt',
#   'suffix-3': 'ent',
#   'word': 'department'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'as',
#   'prefix-1': 's',
#   'prefix-2': 'st',
#   'prefix-3': 'sto',
#   'prev_word': 'department',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'res',
#   'word': 'stores'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'Lord',
#   'prefix-1': 'a',
#   'prefix-2': 'as',
#   'prefix-3': 'as',
#   'prev_word': 'stores',
#   'suffix-1': 's',
#   'suffix-2': 'as',
#   'suffix-3': 'as',
#   'word': 'as'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '&',
#   'prefix-1': 'L',
#   'prefix-2': 'Lo',
#   'prefix-3': 'Lor',
#   'prev_word': 'as',
#   'suffix-1': 'd',
#   'suffix-2': 'rd',
#   'suffix-3': 'ord',
#   'word': 'Lord'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'Taylor',
#   'prefix-1': '&',
#   'prefix-2': '&',
#   'prefix-3': '&',
#   'prev_word': 'Lord',
#   'suffix-1': '&',
#   'suffix-2': '&',
#   'suffix-3': '&',
#   'word': '&'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '.',
#   'prefix-1': 'T',
#   'prefix-2': 'Ta',
#   'prefix-3': 'Tay',
#   'prev_word': '&',
#   'suffix-1': 'r',
#   'suffix-2': 'or',
#   'suffix-3': 'lor',
#   'word': 'Taylor'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': True,
#   'is_numeric': False,
#   'next_word': '',
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'prev_word': 'Taylor',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'word': '.'},
#  {'capitals_inside': True,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': True,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '.',
#   'prefix-1': 'N',
#   'prefix-2': 'N.',
#   'prefix-3': 'N.V',
#   'prev_word': '',
#   'suffix-1': 'V',
#   'suffix-2': '.V',
#   'suffix-3': 'N.V',
#   'word': 'N.V'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'DSM',
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'prev_word': 'N.V',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'word': '.'},
#  {'capitals_inside': True,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'said',
#   'prefix-1': 'D',
#   'prefix-2': 'DS',
#   'prefix-3': 'DSM',
#   'prev_word': '.',
#   'suffix-1': 'M',
#   'suffix-2': 'SM',
#   'suffix-3': 'DSM',
#   'word': 'DSM'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '0',
#   'prefix-1': 's',
#   'prefix-2': 'sa',
#   'prefix-3': 'sai',
#   'prev_word': 'DSM',
#   'suffix-1': 'd',
#   'suffix-2': 'id',
#   'suffix-3': 'aid',
#   'word': 'said'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': True,
#   'next_word': 'net',
#   'prefix-1': '0',
#   'prefix-2': '0',
#   'prefix-3': '0',
#   'prev_word': 'said',
#   'suffix-1': '0',
#   'suffix-2': '0',
#   'suffix-3': '0',
#   'word': '0'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'income',
#   'prefix-1': 'n',
#   'prefix-2': 'ne',
#   'prefix-3': 'net',
#   'prev_word': '0',
#   'suffix-1': 't',
#   'suffix-2': 'et',
#   'suffix-3': 'net',
#   'word': 'net'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'in',
#   'prefix-1': 'i',
#   'prefix-2': 'in',
#   'prefix-3': 'inc',
#   'prev_word': 'net',
#   'suffix-1': 'e',
#   'suffix-2': 'me',
#   'suffix-3': 'ome',
#   'word': 'income'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'i',
#   'prefix-2': 'in',
#   'prefix-3': 'in',
#   'prev_word': 'income',
#   'suffix-1': 'n',
#   'suffix-2': 'in',
#   'suffix-3': 'in',
#   'word': 'in'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'third',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'in',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'quarter',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'thi',
#   'prev_word': 'the',
#   'suffix-1': 'd',
#   'suffix-2': 'rd',
#   'suffix-3': 'ird',
#   'word': 'third'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'jumped',
#   'prefix-1': 'q',
#   'prefix-2': 'qu',
#   'prefix-3': 'qua',
#   'prev_word': 'third',
#   'suffix-1': 'r',
#   'suffix-2': 'er',
#   'suffix-3': 'ter',
#   'word': 'quarter'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '63',
#   'prefix-1': 'j',
#   'prefix-2': 'ju',
#   'prefix-3': 'jum',
#   'prev_word': 'quarter',
#   'suffix-1': 'd',
#   'suffix-2': 'ed',
#   'suffix-3': 'ped',
#   'word': 'jumped'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': True,
#   'next_word': '%',
#   'prefix-1': '6',
#   'prefix-2': '63',
#   'prefix-3': '63',
#   'prev_word': 'jumped',
#   'suffix-1': '3',
#   'suffix-2': '63',
#   'suffix-3': '63',
#   'word': '63'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'as',
#   'prefix-1': '%',
#   'prefix-2': '%',
#   'prefix-3': '%',
#   'prev_word': '63',
#   'suffix-1': '%',
#   'suffix-2': '%',
#   'suffix-3': '%',
#   'word': '%'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'the',
#   'prefix-1': 'a',
#   'prefix-2': 'as',
#   'prefix-3': 'as',
#   'prev_word': '%',
#   'suffix-1': 's',
#   'suffix-2': 'as',
#   'suffix-3': 'as',
#   'word': 'as'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'company',
#   'prefix-1': 't',
#   'prefix-2': 'th',
#   'prefix-3': 'the',
#   'prev_word': 'as',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'the',
#   'word': 'the'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'had',
#   'prefix-1': 'c',
#   'prefix-2': 'co',
#   'prefix-3': 'com',
#   'prev_word': 'the',
#   'suffix-1': 'y',
#   'suffix-2': 'ny',
#   'suffix-3': 'any',
#   'word': 'company'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'substantially',
#   'prefix-1': 'h',
#   'prefix-2': 'ha',
#   'prefix-3': 'had',
#   'prev_word': 'company',
#   'suffix-1': 'd',
#   'suffix-2': 'ad',
#   'suffix-3': 'had',
#   'word': 'had'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'lower',
#   'prefix-1': 's',
#   'prefix-2': 'su',
#   'prefix-3': 'sub',
#   'prev_word': 'had',
#   'suffix-1': 'y',
#   'suffix-2': 'ly',
#   'suffix-3': 'lly',
#   'word': 'substantially'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'extraordinary',
#   'prefix-1': 'l',
#   'prefix-2': 'lo',
#   'prefix-3': 'low',
#   'prev_word': 'substantially',
#   'suffix-1': 'r',
#   'suffix-2': 'er',
#   'suffix-3': 'wer',
#   'word': 'lower'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'charges',
#   'prefix-1': 'e',
#   'prefix-2': 'ex',
#   'prefix-3': 'ext',
#   'prev_word': 'lower',
#   'suffix-1': 'y',
#   'suffix-2': 'ry',
#   'suffix-3': 'ary',
#   'word': 'extraordinary'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '*',
#   'prefix-1': 'c',
#   'prefix-2': 'ch',
#   'prefix-3': 'cha',
#   'prev_word': 'extraordinary',
#   'suffix-1': 's',
#   'suffix-2': 'es',
#   'suffix-3': 'ges',
#   'word': 'charges'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'to',
#   'prefix-1': '*',
#   'prefix-2': '*',
#   'prefix-3': '*',
#   'prev_word': 'charges',
#   'suffix-1': '*',
#   'suffix-2': '*',
#   'suffix-3': '*',
#   'word': '*'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'account',
#   'prefix-1': 't',
#   'prefix-2': 'to',
#   'prefix-3': 'to',
#   'prev_word': '*',
#   'suffix-1': 'o',
#   'suffix-2': 'to',
#   'suffix-3': 'to',
#   'word': 'to'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'for',
#   'prefix-1': 'a',
#   'prefix-2': 'ac',
#   'prefix-3': 'acc',
#   'prev_word': 'to',
#   'suffix-1': 't',
#   'suffix-2': 'nt',
#   'suffix-3': 'unt',
#   'word': 'account'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'a',
#   'prefix-1': 'f',
#   'prefix-2': 'fo',
#   'prefix-3': 'for',
#   'prev_word': 'account',
#   'suffix-1': 'r',
#   'suffix-2': 'or',
#   'suffix-3': 'for',
#   'word': 'for'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'restructuring',
#   'prefix-1': 'a',
#   'prefix-2': 'a',
#   'prefix-3': 'a',
#   'prev_word': 'for',
#   'suffix-1': 'a',
#   'suffix-2': 'a',
#   'suffix-3': 'a',
#   'word': 'a'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'program',
#   'prefix-1': 'r',
#   'prefix-2': 're',
#   'prefix-3': 'res',
#   'prev_word': 'a',
#   'suffix-1': 'g',
#   'suffix-2': 'ng',
#   'suffix-3': 'ing',
#   'word': 'restructuring'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '.',
#   'prefix-1': 'p',
#   'prefix-2': 'pr',
#   'prefix-3': 'pro',
#   'prev_word': 'restructuring',
#   'suffix-1': 'm',
#   'suffix-2': 'am',
#   'suffix-3': 'ram',
#   'word': 'program'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': True,
#   'is_numeric': False,
#   'next_word': '',
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'prev_word': 'program',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'word': '.'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': True,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'Dutch',
#   'prefix-1': 'T',
#   'prefix-2': 'Th',
#   'prefix-3': 'The',
#   'prev_word': '',
#   'suffix-1': 'e',
#   'suffix-2': 'he',
#   'suffix-3': 'The',
#   'word': 'The'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'is_capitalized': True,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'chemical',
#   'prefix-1': 'D',
#   'prefix-2': 'Du',
#   'prefix-3': 'Dut',
#   'prev_word': 'The',
#   'suffix-1': 'h',
#   'suffix-2': 'ch',
#   'suffix-3': 'tch',
#   'word': 'Dutch'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'group',
#   'prefix-1': 'c',
#   'prefix-2': 'ch',
#   'prefix-3': 'che',
#   'prev_word': 'Dutch',
#   'suffix-1': 'l',
#   'suffix-2': 'al',
#   'suffix-3': 'cal',
#   'word': 'chemical'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': 'said',
#   'prefix-1': 'g',
#   'prefix-2': 'gr',
#   'prefix-3': 'gro',
#   'prev_word': 'chemical',
#   'suffix-1': 'p',
#   'suffix-2': 'up',
#   'suffix-3': 'oup',
#   'word': 'group'},
#  {'capitals_inside': False,
#   'has_hyphen': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'is_capitalized': False,
#   'is_first': False,
#   'is_last': False,
#   'is_numeric': False,
#   'next_word': '0',
#   'prefix-1': 's',
#   'prefix-2': 'sa',
#   'prefix-3': 'sai',
#   'prev_word': 'group',
#   'suffix-1': 'd',
#   'suffix-2': 'id',
#   'suffix-3': 'aid',
#   'word': 'said'},
#  ...]

# %%
def pos_tag(sentence):
    tagged_sentence = []
    tags = clf.predict([features(sentence, index) for index in range(len(sentence))])
    return zip(sentence, tags)
print(list(pos_tag(nltk.word_tokenize('This is my friend, John.'))))
# Out:
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'NN'), ('friend', 'NN'), (',', ','), ('John', 'NNP'), ('.', '.')]
