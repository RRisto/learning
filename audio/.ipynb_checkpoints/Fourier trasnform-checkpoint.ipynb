# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack

# %%
#source: https://towardsdatascience.com/fourier-transformation-for-a-data-scientist-1f3731115097

# %%
# Number of samplepoints
N = 600
sample_rate=800.0
# sample spacing - inverse of sample rate
T = 1.0 / sample_rate
x = np.linspace(0.0, N*T, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)

plt.plot(x, y)
# Out:
# C:\Users\risto\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   if __name__ == '__main__':

# %%
fig, ax = plt.subplots()
ax.plot(xf, 2.0/N * np.abs(yf[:N//2]))
plt.show()

# %%
#if you don't take just half
yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(T), N)

fig, ax = plt.subplots()
ax.plot(xf, 2.0/N * np.abs(yf))
plt.show()

# %% [markdown]
# ## My example on windowing

# %%
# Number of samplepoints
N = 600
# sample spacing - inverse of sample rate
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
#take subset of original wave
n_sub=22
x=x[:n_sub]
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)


yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), n_sub)

plt.plot(x, y)

# %%
len(xf), len(yf)
# Out:
# (22, 22)

# %%
fig, ax = plt.subplots()
ax.plot(xf[:n_sub//2], 2.0/N * np.abs(yf[:n_sub//2]))
plt.show()

# %% [markdown]
# #### add window

# %%
nyq_rate = sample_rate / 2.0
nyq_rate
# Out:
# 400.0

# %%
width = 5.0/nyq_rate
width
# Out:
# 0.0125
