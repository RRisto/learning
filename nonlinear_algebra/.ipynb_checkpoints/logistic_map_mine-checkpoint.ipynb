# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## One iteration

# %%
def logistic_iter(x, r):
    "One iteration of the logistic map."
    return r * x - r * x**2

# %%
logistic_iter(0.1, 2.1)
# Out:
# 0.189

# %% [markdown]
# ## Multiple iterations

# %%
def multiple_iterations_seq(x0, r, n_iters=50):
    values=[logistic_iter(x0, r)]
    for _ in range(n_iters):
        values.append(logistic_iter(values[-1], r))
    return values

# %%
values=multiple_iterations_seq(0.1, 2.0)

# %%
plt.plot(values)

# %% [markdown]
# ## Run iters with different r values and see changes

# %%
r = np.linspace(0, 4, num=400)
x0 = np.linspace(0, 1, num=400)
vals = np.empty((r.size, x0.size))
for i in range(vals.shape[0]):
    for j in range(vals.shape[1]):
        seq=multiple_iterations_seq(x0[j], r[i])
        vals[i, j]=seq[-1]

# %%
vals
# Out:
# array([[0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 2.84032583e-105, 5.66623593e-105, ...,
#         5.66623593e-105, 2.84032583e-105, 0.00000000e+000],
#        [0.00000000e+000, 6.39567994e-090, 1.27585714e-089, ...,
#         1.27585714e-089, 6.39567994e-090, 0.00000000e+000],
#        ...,
#        [0.00000000e+000, 9.94907707e-001, 5.06299399e-002, ...,
#         3.77147315e-002, 9.94419183e-001, 0.00000000e+000],
#        [0.00000000e+000, 7.14184571e-002, 5.81598447e-001, ...,
#         9.00857387e-001, 8.55128747e-002, 0.00000000e+000],
#        [0.00000000e+000, 2.24076276e-001, 2.31666234e-001, ...,
#         7.89543681e-001, 3.61423508e-002, 0.00000000e+000]])

# %%
pd.DataFrame(vals)
# Out:
#      0              1              2              3              4    \
# 0    0.0   0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 1    0.0  2.840326e-105  5.666236e-105  8.477732e-105  1.127482e-104
# 2    0.0   6.395680e-90   1.275857e-89   1.908868e-89   2.538603e-89
# 3    0.0   6.116873e-81   1.220207e-80   1.825560e-80   2.427747e-80
# 4    0.0   1.440102e-74   2.872669e-74   4.297706e-74   5.715216e-74
# ..   ...            ...            ...            ...            ...
# 395  0.0   2.542794e-01   3.933620e-02   9.364251e-01   5.627091e-01
# 396  0.0   9.550585e-01   8.696202e-01   4.715591e-01   3.011456e-01
# 397  0.0   9.949077e-01   5.062994e-02   7.397487e-01   9.748573e-01
# 398  0.0   7.141846e-02   5.815984e-01   8.700299e-01   3.168949e-01
# 399  0.0   2.240763e-01   2.316662e-01   9.223426e-02   2.069731e-03
#
#                5              6              7              8    \
# 0     0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
#